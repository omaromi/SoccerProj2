# %%
import pandas as pd
from statsbombpy import sb

comps = sb.competitions()
comps
# Out:
# credentials were not supplied. open data access only
#     competition_id  season_id              country_name  \
# 0               16          4                    Europe
# 1               16          1                    Europe
# 2               16          2                    Europe
# 3               16         27                    Europe
# 4               16         26                    Europe
# 5               16         25                    Europe
# 6               16         24                    Europe
# 7               16         23                    Europe
# 8               16         22                    Europe
# 9               16         21                    Europe
# 10              16         41                    Europe
# 11              16         39                    Europe
# 12              16         37                    Europe
# 13              16         44                    Europe
# 14              16         76                    Europe
# ...

# %%
matches = sb.matches(competition_id=55, season_id=43)
matches.__dict__
# Out:
# credentials were not supplied. open data access only
# {'_is_copy': None,
#  '_mgr': BlockManager
#  Items: Index(['match_id', 'match_date', 'kick_off', 'competition', 'season',
#         'home_team', 'away_team', 'home_score', 'away_score', 'match_status',
#         'match_status_360', 'last_updated', 'last_updated_360', 'match_week',
#         'competition_stage', 'stadium', 'referee', 'home_managers',
#         'away_managers', 'data_version', 'shot_fidelity_version',
#         'xy_fidelity_version'],
#        dtype='object')
#  Axis 1: RangeIndex(start=0, stop=51, step=1)
#  NumericBlock: slice(0, 1, 1), 1 x 51, dtype: int64
#  ObjectBlock: slice(1, 3, 1), 2 x 51, dtype: object
#  ObjectBlock: slice(3, 4, 1), 1 x 51, dtype: object
#  ObjectBlock: slice(4, 5, 1), 1 x 51, dtype: object
#  ObjectBlock: slice(5, 6, 1), 1 x 51, dtype: object
#  ObjectBlock: slice(6, 7, 1), 1 x 51, dtype: object
#  NumericBlock: slice(7, 9, 1), 2 x 51, dtype: int64
# ...

# %%
sb.__dict__
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [15], in <module>
# ----> 1 sb.competition_frames().__dict__
#
# TypeError: competition_frames() missing 3 required positional arguments: 'country', 'division', and 'season'
